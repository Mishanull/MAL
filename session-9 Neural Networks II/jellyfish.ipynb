# %% [markdown]
# # Jellyfish species recognition using CNN
#
# ## Data
#
# Importing all the data. Ignoring the suggested train/test/validation split to avoid overfitting on a particular dataset.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import os
import re

tf.random.set_seed(504)

image_paths = []
for dirname, _, filenames in os.walk('/kaggle/input/jellyfish-types'):
    for filename in filenames:
        image_paths.append(os.path.join(dirname, filename))

match_type = re.compile('.*/([^/]*)_jellyfish.*')
types = [match_type.match(path).group(1) for path in image_paths]
one_hot = pd.get_dummies(types, dtype=int)
labels = one_hot.columns
y = one_hot.to_numpy()

def load_image(path):
    content = tf.io.read_file(path)
    image = tf.io.decode_jpeg(content)
    scaled = tf.image.resize(image, size = (128, 128)) # To make sure all images have same size
    return tf.cast(scaled, tf.float32) / 255

X = np.array([load_image(path) for path in image_paths])

random_jellyfish = [X[np.random.randint(0, len(X)), :, :, :] for i in range(16)]

fig, axes = plt.subplots(4, 4, figsize=(10,10))

for index, kernel in enumerate(random_jellyfish):
    ax=axes[index // 4][index % 4]
    ax.axis('off')
    ax.imshow(kernel)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# The network tends to overfit with only 1879 samples. In order to get more samples, some variations are added to the train and validation data. This helped. The random brightness seemed to do the most difference.
#
# Adding some variation with random noise add is worth a consideration.

# %%
def add_variations(X, y):
    def variations(int_image):
        flip_lr = tf.image.flip_left_right(int_image)
        flip_ud = tf.image.flip_up_down(int_image)
        img180 = tf.image.flip_up_down(flip_lr)
        return [int_image, flip_lr, flip_ud, img180, 
                tf.image.random_brightness(int_image, .1)]
    
    x_element_shape = X.shape[1:]
    y_element_shape = y.shape[1:]
    
    X = np.array([variations(x) for x in X])
    y = np.array([np.full((X.shape[1], *v.shape), v) for v in y])
    
    return X.reshape([-1, *x_element_shape]), y.reshape(-1, *y_element_shape)

    
X_, X_test, y_, y_test = train_test_split(X, y, random_state=504)
X_train, X_valid, y_train, y_valid = train_test_split(X_, y_, random_state=504)
X_train, y_train = add_variations(X_train, y_train)

fig, axes = plt.subplots(4, 4, figsize=(10,10))

for index, kernel in enumerate(X_train[:15]):
    ax=axes[index // 4][index % 4]
    ax.axis('off')
    ax.imshow(kernel)

# %% [markdown]
# ## The Network
# The network ended up quite deep, so I tried Swish instead of ReLU. It didn't seem to matter too much, though.
#
# Keeping the network down to not too many parameters seemed to help overfitting.

# %%
cnn = tf.keras.models.Sequential([
    layers.Input(X_train.shape[1:]),
    layers.Conv2D(3, 3, activation='swish', padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(16, 5, activation='swish', padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='swish', padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='swish', padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='swish', padding='same'),
    layers.MaxPooling2D(),
    layers.SpatialDropout2D(.5),
    layers.Flatten(),
    layers.Dense(units=128, activation='swish'),
    layers.Dropout(.5),
    layers.Dense(units=64, activation='swish'),
    layers.Dropout(.3),
    layers.Dense(units=32, activation='swish'),
    layers.Dropout(.2),
    layers.Dense(units=y.shape[1], activation='softmax')
])

cnn.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0005), metrics = ['accuracy'])
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 3)       84
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 3)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 16)        1216
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  spatial_dropout2d (SpatialD  (None, 4, 4, 128)        0
#  ropout2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 371,098
# Trainable params: 371,098
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Sooner or later the network overfits, so it's good to use early stopping.
#
# I always prefer val_loss as the monitor. If we use val_accuracy we risk overfitting the validation data. 'loss' and 'accuracy' are quite meaningless here.

# %%
es = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 20, restore_best_weights=True)

history = cnn.fit(X_train, y_train, 
                  epochs = 100, 
                  validation_data = (X_valid, y_valid),
                  callbacks = [es])
# Out:
# Epoch 1/100
# 2023-10-29 06:07:50.484697: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 165/165 [==============================] - 16s 14ms/step - loss: 1.6939 - accuracy: 0.2723 - val_loss: 1.5960 - val_accuracy: 0.3144
# Epoch 2/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.4786 - accuracy: 0.3975 - val_loss: 1.3614 - val_accuracy: 0.4278
# Epoch 3/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.3481 - accuracy: 0.4519 - val_loss: 1.2466 - val_accuracy: 0.4816
# Epoch 4/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.2671 - accuracy: 0.4833 - val_loss: 1.1858 - val_accuracy: 0.5156
# Epoch 5/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.2138 - accuracy: 0.5080 - val_loss: 1.1172 - val_accuracy: 0.5581
# Epoch 6/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.1429 - accuracy: 0.5386 - val_loss: 1.0479 - val_accuracy: 0.5892
# Epoch 7/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.0997 - accuracy: 0.5595 - val_loss: 0.9818 - val_accuracy: 0.5949
# Epoch 8/100
# 165/165 [==============================] - 2s 10ms/step - loss: 1.0130 - accuracy: 0.5903 - val_loss: 0.8878 - val_accuracy: 0.6289
# Epoch 9/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.9604 - accuracy: 0.6163 - val_loss: 0.8036 - val_accuracy: 0.6629
# Epoch 10/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.9026 - accuracy: 0.6388 - val_loss: 0.8529 - val_accuracy: 0.6601
# Epoch 11/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.8664 - accuracy: 0.6527 - val_loss: 0.7171 - val_accuracy: 0.7025
# Epoch 12/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.7933 - accuracy: 0.6824 - val_loss: 0.6778 - val_accuracy: 0.7082
# Epoch 13/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.7601 - accuracy: 0.7021 - val_loss: 0.6037 - val_accuracy: 0.7620
# Epoch 14/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.7137 - accuracy: 0.7208 - val_loss: 0.5679 - val_accuracy: 0.7649
# Epoch 15/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.6606 - accuracy: 0.7396 - val_loss: 0.5239 - val_accuracy: 0.7960
# Epoch 16/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.6171 - accuracy: 0.7593 - val_loss: 0.4913 - val_accuracy: 0.8017
# Epoch 17/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.5698 - accuracy: 0.7814 - val_loss: 0.4481 - val_accuracy: 0.8159
# Epoch 18/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.5402 - accuracy: 0.7862 - val_loss: 0.4124 - val_accuracy: 0.8329
# Epoch 19/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.4846 - accuracy: 0.8150 - val_loss: 0.4336 - val_accuracy: 0.8187
# Epoch 20/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.4608 - accuracy: 0.8214 - val_loss: 0.4187 - val_accuracy: 0.8697
# Epoch 21/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.4487 - accuracy: 0.8294 - val_loss: 0.3914 - val_accuracy: 0.8499
# Epoch 22/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.4134 - accuracy: 0.8464 - val_loss: 0.3777 - val_accuracy: 0.8697
# Epoch 23/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.4091 - accuracy: 0.8549 - val_loss: 0.3672 - val_accuracy: 0.8697
# Epoch 24/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.3785 - accuracy: 0.8597 - val_loss: 0.3647 - val_accuracy: 0.8669
# Epoch 25/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.3408 - accuracy: 0.8733 - val_loss: 0.3391 - val_accuracy: 0.8697
# Epoch 26/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.3262 - accuracy: 0.8803 - val_loss: 0.3359 - val_accuracy: 0.8867
# Epoch 27/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2996 - accuracy: 0.8938 - val_loss: 0.3226 - val_accuracy: 0.9093
# Epoch 28/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.3001 - accuracy: 0.8892 - val_loss: 0.2948 - val_accuracy: 0.9037
# Epoch 29/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2648 - accuracy: 0.9013 - val_loss: 0.3191 - val_accuracy: 0.9037
# Epoch 30/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2410 - accuracy: 0.9131 - val_loss: 0.3140 - val_accuracy: 0.8980
# Epoch 31/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2270 - accuracy: 0.9216 - val_loss: 0.3349 - val_accuracy: 0.8980
# Epoch 32/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2439 - accuracy: 0.9138 - val_loss: 0.2735 - val_accuracy: 0.9065
# Epoch 33/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2297 - accuracy: 0.9159 - val_loss: 0.3090 - val_accuracy: 0.9122
# Epoch 34/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.2257 - accuracy: 0.9174 - val_loss: 0.3103 - val_accuracy: 0.9150
# Epoch 35/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1870 - accuracy: 0.9318 - val_loss: 0.2761 - val_accuracy: 0.9150
# Epoch 36/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.2115 - accuracy: 0.9280 - val_loss: 0.2840 - val_accuracy: 0.9093
# Epoch 37/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1796 - accuracy: 0.9367 - val_loss: 0.3048 - val_accuracy: 0.9065
# Epoch 38/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1735 - accuracy: 0.9415 - val_loss: 0.3149 - val_accuracy: 0.9207
# Epoch 39/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1647 - accuracy: 0.9426 - val_loss: 0.2939 - val_accuracy: 0.9207
# Epoch 40/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1651 - accuracy: 0.9436 - val_loss: 0.3039 - val_accuracy: 0.9235
# Epoch 41/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1504 - accuracy: 0.9489 - val_loss: 0.3073 - val_accuracy: 0.9207
# Epoch 42/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1585 - accuracy: 0.9438 - val_loss: 0.4310 - val_accuracy: 0.9037
# Epoch 43/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1560 - accuracy: 0.9487 - val_loss: 0.3704 - val_accuracy: 0.9122
# Epoch 44/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1504 - accuracy: 0.9491 - val_loss: 0.2680 - val_accuracy: 0.9235
# Epoch 45/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1422 - accuracy: 0.9504 - val_loss: 0.2533 - val_accuracy: 0.9320
# Epoch 46/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1202 - accuracy: 0.9572 - val_loss: 0.2759 - val_accuracy: 0.9320
# Epoch 47/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1455 - accuracy: 0.9496 - val_loss: 0.2808 - val_accuracy: 0.9178
# Epoch 48/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1347 - accuracy: 0.9540 - val_loss: 0.2830 - val_accuracy: 0.9235
# Epoch 49/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1196 - accuracy: 0.9572 - val_loss: 0.3298 - val_accuracy: 0.9093
# Epoch 50/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1186 - accuracy: 0.9614 - val_loss: 0.2530 - val_accuracy: 0.9207
# Epoch 51/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1363 - accuracy: 0.9540 - val_loss: 0.2458 - val_accuracy: 0.9292
# Epoch 52/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1197 - accuracy: 0.9617 - val_loss: 0.2616 - val_accuracy: 0.9207
# Epoch 53/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1041 - accuracy: 0.9646 - val_loss: 0.3162 - val_accuracy: 0.9122
# Epoch 54/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1074 - accuracy: 0.9638 - val_loss: 0.3078 - val_accuracy: 0.9207
# Epoch 55/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1023 - accuracy: 0.9676 - val_loss: 0.2901 - val_accuracy: 0.9235
# Epoch 56/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1082 - accuracy: 0.9665 - val_loss: 0.2972 - val_accuracy: 0.9235
# Epoch 57/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.1068 - accuracy: 0.9636 - val_loss: 0.2775 - val_accuracy: 0.9348
# Epoch 58/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0966 - accuracy: 0.9714 - val_loss: 0.2918 - val_accuracy: 0.9320
# Epoch 59/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0976 - accuracy: 0.9708 - val_loss: 0.2314 - val_accuracy: 0.9348
# Epoch 60/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1004 - accuracy: 0.9699 - val_loss: 0.2904 - val_accuracy: 0.9320
# Epoch 61/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1068 - accuracy: 0.9674 - val_loss: 0.3142 - val_accuracy: 0.9263
# Epoch 62/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.1055 - accuracy: 0.9638 - val_loss: 0.3063 - val_accuracy: 0.9150
# Epoch 63/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0763 - accuracy: 0.9752 - val_loss: 0.3652 - val_accuracy: 0.9348
# Epoch 64/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0854 - accuracy: 0.9735 - val_loss: 0.3138 - val_accuracy: 0.9122
# Epoch 65/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0907 - accuracy: 0.9725 - val_loss: 0.3502 - val_accuracy: 0.9093
# Epoch 66/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0913 - accuracy: 0.9720 - val_loss: 0.3561 - val_accuracy: 0.9065
# Epoch 67/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0832 - accuracy: 0.9752 - val_loss: 0.2950 - val_accuracy: 0.9263
# Epoch 68/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0826 - accuracy: 0.9695 - val_loss: 0.4647 - val_accuracy: 0.9008
# Epoch 69/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0721 - accuracy: 0.9765 - val_loss: 0.3444 - val_accuracy: 0.9263
# Epoch 70/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0909 - accuracy: 0.9695 - val_loss: 0.3638 - val_accuracy: 0.9263
# Epoch 71/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0852 - accuracy: 0.9756 - val_loss: 0.3234 - val_accuracy: 0.9207
# Epoch 72/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0665 - accuracy: 0.9788 - val_loss: 0.3720 - val_accuracy: 0.9292
# Epoch 73/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0775 - accuracy: 0.9744 - val_loss: 0.2998 - val_accuracy: 0.9320
# Epoch 74/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0632 - accuracy: 0.9809 - val_loss: 0.3167 - val_accuracy: 0.9348
# Epoch 75/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0665 - accuracy: 0.9797 - val_loss: 0.3921 - val_accuracy: 0.9150
# Epoch 76/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0645 - accuracy: 0.9809 - val_loss: 0.3142 - val_accuracy: 0.9292
# Epoch 77/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0791 - accuracy: 0.9765 - val_loss: 0.2932 - val_accuracy: 0.9377
# Epoch 78/100
# 165/165 [==============================] - 2s 10ms/step - loss: 0.0819 - accuracy: 0.9765 - val_loss: 0.3304 - val_accuracy: 0.9320
# Epoch 79/100
# 165/165 [==============================] - 2s 11ms/step - loss: 0.0662 - accuracy: 0.9797 - val_loss: 0.3284 - val_accuracy: 0.9235

# %% [markdown]
# ## The outcome
#
# We see the overfitting clearly below.

# %%
figure = plt.figure(figsize=(20, 10))
ax = figure.add_subplot(1, 2, 1, title='Learning curves (loss)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.plot(history.history['loss'], label = 'train')
ax.plot(history.history['val_loss'], label = 'valid')
ax.legend()

ax = figure.add_subplot(1, 2, 2, title='Learning curves (accuracy)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.plot(history.history['accuracy'], label = 'train')
ax.plot(history.history['val_accuracy'], label = 'valid')
ax.legend()

plt.show()

# %% [markdown]
# The final result is okay, though.

# %%
train_eval = cnn.evaluate(X_train, y_train)
validation_eval = cnn.evaluate(X_valid, y_valid)
test_eval = cnn.evaluate(X_test, y_test)
print("Error on test data: {p:.2f}%".format(p = 100*(1-test_eval[1])))
# Out:
# 165/165 [==============================] - 1s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2314 - accuracy: 0.9348
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1996 - accuracy: 0.9511
# Error on test data: 4.89%

# %% [markdown]
# ## Feature maps

# %%
plt.axis('off')
plt.imshow(X_test[0])

plt.show()

# %% [markdown]
# ### Lowest convolutional layer

# %% [markdown]
# This was meant as a learnable resize layer, but interestingly it's extracted some features.

# %%
convolutional_layer = tf.keras.models.Sequential(cnn.layers[0: 2])
feature_maps = convolutional_layer(X_test[0:1])

fig, axes = plt.subplots(1, 3, figsize=(21,7))
for index in range(3):
    ax=axes[index]
    ax.axis('off')
    ax.imshow(feature_maps[0, :, :, index], cmap='gray')

# %%
from matplotlib.colors import rgb_to_hsv

hsv = rgb_to_hsv(X_test[0])

fig, axes = plt.subplots(1, 3, figsize=(21,7))

axes[0].axis('off')
axes[0].imshow(hsv[:, :, 2], cmap='gray')

axes[1].axis('off')
axes[1].imshow(1-hsv[:, :, 1], cmap='gray')


axes[2].axis('off')
axes[2].imshow(hsv[:, :, 0], cmap='gray')

# %% [markdown]
# ### Second convolutional layer

# %%
early_layers = cnn.layers[0:4]
part_cnn = tf.keras.models.Sequential(early_layers)
feature_maps2 = part_cnn.predict(X_test[0: 1])

size = feature_maps2.shape[3]
ncols = 4
nrows = (size - 1) // 4 + 1

fig, axes = plt.subplots(nrows, ncols, figsize=(16,16))
for index in range(size):
    ax=axes[index // ncols][index % ncols]
    ax.axis('off')
    ax.imshow(feature_maps2[0, :, :, index], cmap='gray')
# Out:
# 1/1 [==============================] - 0s 118ms/step

# %% [markdown]
# ### Third convolutional layer

# %%
early_layers = cnn.layers[0:6]
part_cnn = tf.keras.models.Sequential(early_layers)
feature_maps3 = part_cnn.predict(X_test[0: 1])

size = feature_maps3.shape[3]
ncols = 6
nrows = (size - 1) // ncols + 1

fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 4 * nrows))
for index in range(ncols * nrows):
    ax=axes[index // ncols][index % ncols]
    ax.axis('off')
    if index < size:
        ax.imshow(feature_maps3[0, :, :, index], cmap='gray')
# Out:
# 1/1 [==============================] - 0s 106ms/step

# %% [markdown]
# ### Fourth convolutional layer

# %%
early_layers = cnn.layers[0:8]
part_cnn = tf.keras.models.Sequential(early_layers)
feature_maps4 = part_cnn.predict(X_test[0: 1])

size = feature_maps4.shape[3]
ncols = 8
nrows = (size - 1) // ncols + 1

fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 4 * nrows))
for index in range(ncols * nrows):
    ax=axes[index // ncols][index % ncols]
    ax.axis('off')
    if index < size:
        ax.imshow(feature_maps4[0, :, :, index], cmap='gray')
# Out:
# 1/1 [==============================] - 0s 134ms/step

# %% [markdown]
# ### Highest convolutional layer

# %%
early_layers = cnn.layers[0:10]
part_cnn = tf.keras.models.Sequential(early_layers)
feature_maps5 = part_cnn.predict(X_test[0: 1])

size = feature_maps5.shape[3]
ncols = 8
nrows = (size - 1) // ncols + 1

fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 4 * nrows))
for index in range(ncols * nrows):
    ax=axes[index // ncols][index % ncols]
    ax.axis('off')
    if index < size:
        ax.imshow(feature_maps5[0, :, :, index], cmap='gray')
# Out:
# 1/1 [==============================] - 0s 156ms/step
